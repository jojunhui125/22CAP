# %% [markdown]
# <a href="https://colab.research.google.com/github/jojunhui125/22CAP/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /
from glob import glob
img_list = glob('/content/dataset/Car_IncheonIN_DataSet-1/train/images/*.jpg')
print(len(img_list))
# Out:
# /
# 42

# %%
from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size=0.2,random_state=2000)

print(len(train_img_list),len(val_img_list))
# Out:
# 33 9

# %%
with open('/content/dataset/train.txt','w') as f:
    f.write('\n'.join(train_img_list) + '\n')
with open('/content/dataset/val.txt','w') as f:
    f.write('\n'.join(val_img_list)+'\n')

# %%
import yaml
 
with open('/content/dataset/Car_IncheonIN_DataSet-1/data.yaml', 'r') as f:
	data = yaml.full_load(f)
    
print(data)
 
data['train'] = '/content/dataset/train.txt'
data['val'] = '/content/dataset/val.txt'
 
with open('/content/dataset/Car_IncheonIN_DataSet-1/data.yaml', 'w') as f:
	yaml.dump(data, f)
# Out:
# {'names': ['CarIncheonINDataSet'], 'nc': 1, 'train': 'Car_IncheonIN_DataSet-1/train/images', 'val': 'Car_IncheonIN_DataSet-1/valid/images'}

# %%
# %cd /content/yolov5/

# !python train.py --img 416 --batch 16 --epochs 50 --data /content/dataset/Car_IncheonIN_DataSet-1/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name car_yolov5s_result
# Out:
# /content/yolov5
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/content/dataset/Car_IncheonIN_DataSet-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=car_yolov5s_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.2-120-g2ac4b63 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/car_yolov5s_result/weights/best.pt --img 416 --conf 0.4 --source /content/yolov5/test
# Out:
# detect: weights=['runs/train/car_yolov5s_result/weights/best.pt'], source=/content/yolov5/test, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-120-g2ac4b63 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/test/car1.PNG: 288x416 1 CarIncheonINDataSet, 11.9ms
# Speed: 0.3ms pre-process, 11.9ms inference, 1.9ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp
